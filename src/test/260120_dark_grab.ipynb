# %%
import sys
sys.path.insert(0, "/home/GAFOL/work/kspec_gfa_controller/src")  # <-- add *src*, not the package folder

from kspec_gfa_controller.gfa_actions import GFAActions

# %%
actions = GFAActions()
# Out:
# 2026-01-20 02:02:03,297 [INFO] Initialized GFAEnvironment with role 'plate' and cameras [1, 2, 3, 4, 5, 6]
# 2026-01-20 02:02:03,297 [INFO] Initializing GFAController with provided config.
# 2026-01-20 02:02:03,298 [INFO] GFAController initialization complete.
# 2026-01-20 02:02:03,298 [INFO] Initializing gfa_astrometry class.
# 2026-01-20 02:02:03,299 [INFO] Initializing GFAGuider...
# 2026-01-20 02:02:03,300 [DEBUG] Processed dir: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/procimg
# 2026-01-20 02:02:03,300 [DEBUG] Final astro dir: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/astroimg/
# 2026-01-20 02:02:03,300 [DEBUG] Cutout dir: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/cutout
# 2026-01-20 02:02:03,300 [INFO] GFAGuider setup complete.

# %%
# dark 1s
for i in range:
    await actions.grab(CamNum=0, ExpTime=i, path="./img/dark")
# Out:
# 2026-01-20 02:02:03,306 [INFO] Open all plate cameras...
# 2026-01-20 02:02:03,306 [INFO] Opening all cameras...
# 2026-01-20 02:02:03,872 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-20 02:02:03,893 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-20 02:02:03,895 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-20 02:02:03,907 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-20 02:02:03,918 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-20 02:02:03,930 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-20 02:02:03,930 [INFO] All cameras opened successfully.
# 2026-01-20 02:02:03,948 [ERROR] Error during grabbing camera 3: Value 0.000000 must be greater than or equal 18.000000. : OutOfRangeException thrown in node 'ExposureTime' while calling 'ExposureTime.SetValue()' (file 'FloatT.h', line 87)
# 2026-01-20 02:02:03,948 [ERROR] Error during grabbing camera 2: Value 0.000000 must be greater than or equal 18.000000. : OutOfRangeException thrown in node 'ExposureTime' while calling 'ExposureTime.SetValue()' (file 'FloatT.h', line 87)
# 2026-01-20 02:02:03,949 [ERROR] Error during grabbing camera 1: Value 0.000000 must be greater than or equal 18.000000. : OutOfRangeException thrown in node 'ExposureTime' while calling 'ExposureTime.SetValue()' (file 'FloatT.h', line 87)
# 2026-01-20 02:02:03,949 [ERROR] Error during grabbing camera 4: Value 0.000000 must be greater than or equal 18.000000. : OutOfRangeException thrown in node 'ExposureTime' while calling 'ExposureTime.SetValue()' (file 'FloatT.h', line 87)
# 2026-01-20 02:02:03,949 [ERROR] Error during grabbing camera 5: Value 0.000000 must be greater than or equal 18.000000. : OutOfRangeException thrown in node 'ExposureTime' while calling 'ExposureTime.SetValue()' (file 'FloatT.h', line 87)
# 2026-01-20 02:02:03,951 [ERROR] Error during grabbing camera 6: Value 0.000000 must be greater than or equal 18.000000. : OutOfRangeException thrown in node 'ExposureTime' while calling 'ExposureTime.SetValue()' (file 'FloatT.h', line 87)
# 2026-01-20 02:02:03,952 [INFO] Close all plate cameras...
# 2026-01-20 02:02:03,952 [INFO] Closing all cameras...
# 2026-01-20 02:02:03,956 [INFO] Cam1 closed.
# 2026-01-20 02:02:03,956 [INFO] Cam6 closed.
# 2026-01-20 02:02:03,957 [INFO] Cam2 closed.
# 2026-01-20 02:02:03,957 [INFO] Cam5 closed.
# 2026-01-20 02:02:03,957 [INFO] Cam4 closed.
# 2026-01-20 02:02:03,958 [INFO] Cam3 closed.
# 2026-01-20 02:02:03,958 [INFO] All cameras closed.
# 2026-01-20 02:02:03,974 [INFO] Open all plate cameras...
# 2026-01-20 02:02:03,975 [INFO] Opening all cameras...
# 2026-01-20 02:02:04,503 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-20 02:02:04,513 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-20 02:02:04,523 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-20 02:02:04,533 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-20 02:02:04,544 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-20 02:02:04,555 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-20 02:02:04,556 [INFO] All cameras opened successfully.
# 2026-01-20 02:02:05,917 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170205_40103667_exp1s.fits
# 2026-01-20 02:02:05,917 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:05,917 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:05,918 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:05,919 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:05'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    1                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:05,924 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170205_40103667_exp1s.fits
# 2026-01-20 02:02:06,122 [INFO] PNG file saved: ./png/D20260119_T170205_40103667_exp1s.png
# 2026-01-20 02:02:06,124 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170206_40103833_exp1s.fits
# 2026-01-20 02:02:06,124 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:06,125 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:06,125 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:06,126 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:06'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    1                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:06,130 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170206_40103833_exp1s.fits
# 2026-01-20 02:02:06,358 [INFO] PNG file saved: ./png/D20260119_T170206_40103833_exp1s.png
# 2026-01-20 02:02:06,359 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170206_40103834_exp1s.fits
# 2026-01-20 02:02:06,359 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:06,360 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:06,360 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:06,361 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:06'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    1                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:06,365 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170206_40103834_exp1s.fits
# 2026-01-20 02:02:06,628 [INFO] PNG file saved: ./png/D20260119_T170206_40103834_exp1s.png
# 2026-01-20 02:02:06,630 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170206_40103831_exp1s.fits
# 2026-01-20 02:02:06,630 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:06,630 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:06,631 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:06,631 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:06'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    1                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:06,636 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170206_40103831_exp1s.fits
# 2026-01-20 02:02:06,804 [INFO] PNG file saved: ./png/D20260119_T170206_40103831_exp1s.png
# 2026-01-20 02:02:06,806 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170206_40103651_exp1s.fits
# 2026-01-20 02:02:06,806 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:06,806 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:06,807 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:06,807 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:06'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    1                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:06,812 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170206_40103651_exp1s.fits
# 2026-01-20 02:02:07,011 [INFO] PNG file saved: ./png/D20260119_T170206_40103651_exp1s.png
# 2026-01-20 02:02:07,012 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170207_40103663_exp1s.fits
# 2026-01-20 02:02:07,012 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:07,012 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:07,013 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:07,013 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:07'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    1                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:07,017 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170207_40103663_exp1s.fits
# 2026-01-20 02:02:07,343 [INFO] PNG file saved: ./png/D20260119_T170207_40103663_exp1s.png
# 2026-01-20 02:02:07,344 [INFO] Close all plate cameras...
# 2026-01-20 02:02:07,345 [INFO] Closing all cameras...
# 2026-01-20 02:02:07,348 [INFO] Cam6 closed.
# 2026-01-20 02:02:07,349 [INFO] Cam4 closed.
# 2026-01-20 02:02:07,349 [INFO] Cam2 closed.
# 2026-01-20 02:02:07,349 [INFO] Cam5 closed.
# 2026-01-20 02:02:07,349 [INFO] Cam3 closed.
# 2026-01-20 02:02:07,350 [INFO] Cam1 closed.
# 2026-01-20 02:02:07,350 [INFO] All cameras closed.
# 2026-01-20 02:02:07,360 [INFO] Open all plate cameras...
# 2026-01-20 02:02:07,361 [INFO] Opening all cameras...
# 2026-01-20 02:02:07,882 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-20 02:02:07,891 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-20 02:02:07,900 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-20 02:02:07,910 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-20 02:02:07,919 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-20 02:02:07,929 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-20 02:02:07,929 [INFO] All cameras opened successfully.
# 2026-01-20 02:02:10,290 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170210_40103834_exp2s.fits
# 2026-01-20 02:02:10,291 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:10,292 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:10,292 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:10,293 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:10'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    2                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:10,300 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170210_40103834_exp2s.fits
# 2026-01-20 02:02:10,552 [INFO] PNG file saved: ./png/D20260119_T170210_40103834_exp2s.png
# 2026-01-20 02:02:10,553 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170210_40103651_exp2s.fits
# 2026-01-20 02:02:10,553 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:10,553 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:10,554 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:10,555 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:10'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    2                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:10,559 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170210_40103651_exp2s.fits
# 2026-01-20 02:02:10,770 [INFO] PNG file saved: ./png/D20260119_T170210_40103651_exp2s.png
# 2026-01-20 02:02:10,771 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170210_40103667_exp2s.fits
# 2026-01-20 02:02:10,772 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:10,772 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:10,772 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:10,773 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:10'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    2                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:10,779 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170210_40103667_exp2s.fits
# 2026-01-20 02:02:11,088 [INFO] PNG file saved: ./png/D20260119_T170210_40103667_exp2s.png
# 2026-01-20 02:02:11,090 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170211_40103833_exp2s.fits
# 2026-01-20 02:02:11,090 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:11,090 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:11,091 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:11,091 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:11'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    2                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:11,096 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170211_40103833_exp2s.fits
# 2026-01-20 02:02:11,346 [INFO] PNG file saved: ./png/D20260119_T170211_40103833_exp2s.png
# 2026-01-20 02:02:11,347 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170211_40103831_exp2s.fits
# 2026-01-20 02:02:11,348 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:11,348 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:11,348 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:11,349 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:11'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    2                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:11,353 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170211_40103831_exp2s.fits
# 2026-01-20 02:02:11,623 [INFO] PNG file saved: ./png/D20260119_T170211_40103831_exp2s.png
# 2026-01-20 02:02:11,624 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170211_40103663_exp2s.fits
# 2026-01-20 02:02:11,625 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:11,625 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:11,625 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:02:11,626 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:02:11'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    2                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:02:11,630 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170211_40103663_exp2s.fits
# 2026-01-20 02:02:11,827 [INFO] PNG file saved: ./png/D20260119_T170211_40103663_exp2s.png
# 2026-01-20 02:02:11,828 [INFO] Close all plate cameras...
# 2026-01-20 02:02:11,828 [INFO] Closing all cameras...
# 2026-01-20 02:02:11,832 [INFO] Cam2 closed.
# 2026-01-20 02:02:11,833 [INFO] Cam5 closed.
# 2026-01-20 02:02:11,833 [INFO] Cam4 closed.
# 2026-01-20 02:02:11,833 [INFO] Cam6 closed.
# 2026-01-20 02:02:11,833 [INFO] Cam3 closed.
# 2026-01-20 02:02:11,833 [INFO] Cam1 closed.
# 2026-01-20 02:02:11,833 [INFO] All cameras closed.
# 2026-01-20 02:02:11,844 [INFO] Open all plate cameras...
# 2026-01-20 02:02:11,844 [INFO] Opening all cameras...
# 2026-01-20 02:02:12,368 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-20 02:02:12,378 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-20 02:02:12,387 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-20 02:02:12,396 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-20 02:02:12,405 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-20 02:02:12,415 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-20 02:02:12,415 [INFO] All cameras opened successfully.
# 2026-01-20 02:02:15,776 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170215_40103667_exp3s.fits
# 2026-01-20 02:02:15,776 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:02:15,777 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:02:15,777 [WARNING] No time_obs provided. Using current time.
# ...
# 2026-01-20 02:03:08,535 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170308_40103831_exp9s.fits
# 2026-01-20 02:03:08,738 [INFO] PNG file saved: ./png/D20260119_T170308_40103831_exp9s.png
# 2026-01-20 02:03:08,740 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170308_40103651_exp9s.fits
# 2026-01-20 02:03:08,740 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:03:08,740 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:03:08,741 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:03:08,741 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:03:08'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    9                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:03:08,745 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170308_40103651_exp9s.fits
# 2026-01-20 02:03:08,823 [INFO] PNG file saved: ./png/D20260119_T170308_40103651_exp9s.png
# 2026-01-20 02:03:08,825 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170308_40103667_exp9s.fits
# 2026-01-20 02:03:08,825 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:03:08,825 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:03:08,826 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:03:08,826 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:03:08'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    9                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:03:08,830 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170308_40103667_exp9s.fits
# 2026-01-20 02:03:08,953 [INFO] PNG file saved: ./png/D20260119_T170308_40103667_exp9s.png
# 2026-01-20 02:03:08,954 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170308_40103833_exp9s.fits
# 2026-01-20 02:03:08,955 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:03:08,955 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:03:08,955 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:03:08,956 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:03:08'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    9                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:03:08,960 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170308_40103833_exp9s.fits
# 2026-01-20 02:03:09,165 [INFO] PNG file saved: ./png/D20260119_T170308_40103833_exp9s.png
# 2026-01-20 02:03:09,167 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170309_40103663_exp9s.fits
# 2026-01-20 02:03:09,167 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:03:09,167 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:03:09,167 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:03:09,168 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:03:09'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                    9                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:03:09,172 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170309_40103663_exp9s.fits
# 2026-01-20 02:03:09,490 [INFO] PNG file saved: ./png/D20260119_T170309_40103663_exp9s.png
# 2026-01-20 02:03:09,491 [INFO] Close all plate cameras...
# 2026-01-20 02:03:09,491 [INFO] Closing all cameras...
# 2026-01-20 02:03:09,495 [INFO] Cam1 closed.
# 2026-01-20 02:03:09,495 [INFO] Cam5 closed.
# 2026-01-20 02:03:09,495 [INFO] Cam2 closed.
# 2026-01-20 02:03:09,496 [INFO] Cam4 closed.
# 2026-01-20 02:03:09,496 [INFO] Cam3 closed.
# 2026-01-20 02:03:09,496 [INFO] Cam6 closed.
# 2026-01-20 02:03:09,496 [INFO] All cameras closed.

# %%
await actions.grab(CamNum=0, ExpTime=10, path="./img/dark")
# Out:
# 2026-01-20 02:04:42,795 [INFO] Open all plate cameras...
# 2026-01-20 02:04:42,795 [INFO] Opening all cameras...
# 2026-01-20 02:04:43,316 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-20 02:04:43,325 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-20 02:04:43,335 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-20 02:04:43,344 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-20 02:04:43,353 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-20 02:04:43,364 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-20 02:04:43,364 [INFO] All cameras opened successfully.
# 2026-01-20 02:04:53,725 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170453_40103651_exp10s.fits
# 2026-01-20 02:04:53,725 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:04:53,726 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:04:53,726 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:04:53,727 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:04:53'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                   10                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:04:53,733 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170453_40103651_exp10s.fits
# 2026-01-20 02:04:53,869 [INFO] PNG file saved: ./png/D20260119_T170453_40103651_exp10s.png
# 2026-01-20 02:04:53,871 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170453_40103667_exp10s.fits
# 2026-01-20 02:04:53,872 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:04:53,873 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:04:53,873 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:04:53,874 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:04:53'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                   10                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:04:53,881 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170453_40103667_exp10s.fits
# 2026-01-20 02:04:53,998 [INFO] PNG file saved: ./png/D20260119_T170453_40103667_exp10s.png
# 2026-01-20 02:04:53,999 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170453_40103833_exp10s.fits
# 2026-01-20 02:04:53,999 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:04:54,000 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:04:54,000 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:04:54,001 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:04:54'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                   10                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:04:54,005 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170453_40103833_exp10s.fits
# 2026-01-20 02:04:54,120 [INFO] PNG file saved: ./png/D20260119_T170453_40103833_exp10s.png
# 2026-01-20 02:04:54,121 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170454_40103834_exp10s.fits
# 2026-01-20 02:04:54,122 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:04:54,122 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:04:54,122 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:04:54,123 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:04:54'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                   10                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:04:54,128 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170454_40103834_exp10s.fits
# 2026-01-20 02:04:54,264 [INFO] PNG file saved: ./png/D20260119_T170454_40103834_exp10s.png
# 2026-01-20 02:04:54,265 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170454_40103831_exp10s.fits
# 2026-01-20 02:04:54,265 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:04:54,266 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:04:54,266 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:04:54,267 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:04:54'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                   10                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:04:54,271 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170454_40103831_exp10s.fits
# 2026-01-20 02:04:54,413 [INFO] PNG file saved: ./png/D20260119_T170454_40103831_exp10s.png
# 2026-01-20 02:04:54,414 [DEBUG] FITS file will be saved to: ./img/dark/D20260119_T170454_40103663_exp10s.fits
# 2026-01-20 02:04:54,414 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-20 02:04:54,414 [WARNING] No date_obs provided. Using current date.
# 2026-01-20 02:04:54,415 [WARNING] No time_obs provided. Using current time.
# 2026-01-20 02:04:54,416 [DEBUG] FITS header details: SIMPLE  =                    T                                                  BITPIX  =                  -32                                                  NAXIS   =                    2                                                  NAXIS1  =                 1332                                                  NAXIS2  =                 1152                                                  CTYPE1  = 'PIXEL   '                                                            CTYPE2  = 'PIXEL   '                                                            TELESCOP= 'KMTNET  '                                                            INSTRUME= 'KSPEC-GFA'                                                           OBSERVER= 'Mingyeong'                                                           OBJECT  = 'Unknown '                                                            DATE-OBS= '2026-01-20'                                                          TIME-OBS= '02:04:54'                                                            RA      = 'UNKNOWN '                                                            DEC     = 'UNKNOWN '                                                            EXPTIME =                   10                                                  COMMENT FITS file created with custom header fields                             END
# 2026-01-20 02:04:54,420 [INFO] FITS file successfully saved to ./img/dark/D20260119_T170454_40103663_exp10s.fits
# 2026-01-20 02:04:54,666 [INFO] PNG file saved: ./png/D20260119_T170454_40103663_exp10s.png
# 2026-01-20 02:04:54,667 [INFO] Close all plate cameras...
# 2026-01-20 02:04:54,668 [INFO] Closing all cameras...
# 2026-01-20 02:04:54,672 [INFO] Cam1 closed.
# 2026-01-20 02:04:54,672 [INFO] Cam5 closed.
# 2026-01-20 02:04:54,672 [INFO] Cam3 closed.
# 2026-01-20 02:04:54,672 [INFO] Cam4 closed.
# 2026-01-20 02:04:54,673 [INFO] Cam6 closed.
# 2026-01-20 02:04:54,673 [INFO] Cam2 closed.
# 2026-01-20 02:04:54,673 [INFO] All cameras closed.
# {'status': 'success', 'message': 'Images grabbed from all cameras.'}
