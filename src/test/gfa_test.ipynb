# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from gfa_actions import GFAActions

actions = GFAActions()

# %%
actions.status()

# %%
from astropy.io import fits
import glob

for fp in glob.glob("../img/astroimg/*.fits", recursive=True)[:10]:
    with fits.open(fp) as hdul:
        hdr = hdul[0].header
        print(fp)
        print("  SIMPLE:", hdr.get("SIMPLE"), "NAXIS:", hdr.get("NAXIS"))
        print("  CRVAL1/2:", hdr.get("CRVAL1"), hdr.get("CRVAL2"))
        print("  OBJECT:", hdr.get("OBJECT"))
        print()

# %%
# put your FITS into ../img/raw first (relative to notebook), then:
await actions.guiding_from_files(save=False)
