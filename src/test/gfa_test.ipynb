# %%
import sys
sys.path.insert(0, "/home/GAFOL/work/kspec_gfa_controller/src")  # <-- add *src*, not the package folder

from kspec_gfa_controller.gfa_actions import GFAActions
from kspec_gfa_controller.gfa_controller import GFAController
# or (if __init__.py exports it):
# from kspec_gfa_controller import GFAActions

# %%
actions = GFAActions()
# Out:
# 2026-01-16 15:44:20,262 [INFO] Initialized GFAEnvironment with role 'plate' and cameras [1, 2, 3, 4, 5, 6]
# 2026-01-16 15:44:20,262 [INFO] Initializing GFAController with provided config.
# 2026-01-16 15:44:20,263 [INFO] GFAController initialization complete.
# 2026-01-16 15:44:20,263 [INFO] Initializing gfa_astrometry class.
# 2026-01-16 15:44:20,263 [INFO] Initializing GFAGuider...
# 2026-01-16 15:44:20,264 [DEBUG] Processed dir: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/procimg
# 2026-01-16 15:44:20,264 [DEBUG] Final astro dir: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/astroimg/
# 2026-01-16 15:44:20,264 [DEBUG] Cutout dir: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/cutout
# 2026-01-16 15:44:20,264 [INFO] GFAGuider setup complete.

# %%
await actions.grab(ExpTime=0.01)
# Out:
# 2026-01-16 15:50:36,531 [INFO] Open all plate cameras...
# 2026-01-16 15:50:36,532 [INFO] Opening all cameras...
# 2026-01-16 15:50:37,055 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-16 15:50:37,065 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-16 15:50:37,075 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-16 15:50:37,084 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-16 15:50:37,095 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-16 15:50:37,105 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-16 15:50:37,105 [INFO] All cameras opened successfully.
# 2026-01-16 15:50:37,430 [DEBUG] FITS file will be saved to: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/grab/2026-01-16/D20260116_T065037_40103667_exp0s.fits
# 2026-01-16 15:50:37,430 [DEBUG] Image array shape: (1152, 1332)
# 2026-01-16 15:50:37,430 [WARNING] No date_obs provided. Using current date.
# 2026-01-16 15:50:37,430 [WARNING] No time_obs provided. Using current time.
# ...
