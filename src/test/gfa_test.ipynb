# %%
import sys
sys.path.insert(0, "/home/GAFOL/work/kspec_gfa_controller/src")  # <-- add *src*, not the package folder

from kspec_gfa_controller.gfa_actions import GFAActions

# %%
from astropy.io import fits

def print_ra_dec(fits_path):
    with fits.open(fits_path) as hdul:
        hdr = hdul[0].header
        ra = hdr.get('RA')
        dec = hdr.get('DEC')
        print(f"RA: {ra}, DEC: {dec}")

# 사용 예
print_ra_dec("/home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/raw/D20260121_T174426_40103651_exp5s.fits")
# Out:
# RA: 09:09:14.35, DEC: -37:10:05.78

# %%
actions = GFAActions()
# Out:
# 2026-01-22 14:34:51,113 [INFO] Initialized GFAEnvironment with role 'plate' and cameras [1, 2, 3, 4, 5, 6]
# 2026-01-22 14:34:51,113 [INFO] Initializing GFAController with provided config.
# 2026-01-22 14:34:51,113 [INFO] GFAController initialization complete.
# 2026-01-22 14:34:51,114 [INFO] Initializing gfa_astrometry class.
# 2026-01-22 14:34:51,114 [INFO] Paths:
# 2026-01-22 14:34:51,114 [INFO]   raw_images        = /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/raw
# 2026-01-22 14:34:51,114 [INFO]   temp_files        = /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/tempfiles
# 2026-01-22 14:34:51,115 [INFO]   final_astrometry  = /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/astroimg/
# 2026-01-22 14:34:51,115 [INFO]   star_catalog_dir  = /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/star_catalog
# ...

# %%
#await actions.grab(ExpTime=0.05) # RA, DEC

# %%
#RA: 09:09:14.35, DEC: -37:10:05.78
await actions.guiding(ra="09:09:14.35", dec="-37:10:05.78", save=False) # RA, DEC
# Out:
# 2026-01-22 14:43:10,724 [INFO] Starting guiding sequence...
# 2026-01-22 14:43:10,724 [INFO] Opening all cameras...
# 2026-01-22 14:43:11,247 [INFO] Cam4 opened (IP 192.168.88.4).
# 2026-01-22 14:43:11,256 [INFO] Cam6 opened (IP 192.168.88.6).
# 2026-01-22 14:43:11,265 [INFO] Cam2 opened (IP 192.168.88.2).
# 2026-01-22 14:43:11,275 [INFO] Cam3 opened (IP 192.168.88.3).
# 2026-01-22 14:43:11,284 [INFO] Cam5 opened (IP 192.168.88.5).
# 2026-01-22 14:43:11,294 [INFO] Cam1 opened (IP 192.168.88.1).
# 2026-01-22 14:43:11,295 [INFO] All cameras opened successfully.
# 2026-01-22 14:43:11,295 [INFO] Closing all cameras...
# 2026-01-22 14:43:11,298 [INFO] Cam5 closed.
# 2026-01-22 14:43:11,299 [INFO] Cam6 closed.
# 2026-01-22 14:43:11,299 [INFO] Cam2 closed.
# 2026-01-22 14:43:11,299 [INFO] Cam4 closed.
# 2026-01-22 14:43:11,299 [INFO] Cam3 closed.
# 2026-01-22 14:43:11,300 [INFO] Cam1 closed.
# 2026-01-22 14:43:11,300 [INFO] All cameras closed.
# ...

# %%
#solve-field 
# ./clean/D20260119_T133618_40103834_exp1s_hotpix_1p5med.fits   
# -D /tmp/gfa_xyls_solve   -O --no-plots --no-verify --crpix-center   
# -X X -Y Y -s FLUX   --scale-units degwidth -L 0.12 -H 0.22   
# --ra "06:57:31.68" --dec "-29:06:02.30" --radius 2   -l 120  -c 0.1 -E 2

# %%
hdul = fits.open("/home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/star_catalog/combined_star.fits")
hdul.info()
# Out:
# Filename: /home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/star_catalog/combined_star.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     34   233R x 13C   [D, D, D, D, D, D, D, D, J, J, D, E, E]

# %%
from astropy.table import Table

tbl = Table.read("/home/GAFOL/work/kspec_gfa_controller/src/kspec_gfa_controller/img/star_catalog/combined_star.fits")
print(tbl)
# Out:
#      field_x            field_y       ...    FLUX   BACKGROUND
# ------------------ ------------------ ... --------- ----------
#  912.6415405273438 164.09681701660156 ... 4078.6582  16.341797
#  634.8501586914062  148.8553009033203 ... 4077.2793  17.720703
# 1125.6429443359375  486.4548645019531 ... 4074.4724  20.527588
#     919.4501953125   813.489501953125 ... 4069.6387  25.361328
#  861.9072875976562  684.2720336914062 ... 3335.6306  23.369385
#  882.1135864257812  784.2274169921875 ... 3135.9934  25.006592
#  238.6834259033203  618.9656372070312 ... 1305.6031   29.39685
#   1315.53564453125   628.548583984375 ... 4073.4702  21.529785
#    600.76416015625 1050.7122802734375 ... 2784.6426  30.357422
#   788.781494140625    260.19580078125 ... 1986.0812  17.918823
#                ...                ... ...       ...        ...
#  733.5498657226562  758.3531494140625 ... 4075.8914  19.108643
#  711.5477294921875  1082.200439453125 ... 2472.0125  23.987549
# ...

# %%
import pandas as pd

df = tbl.to_pandas()
df.head()
# Out:
#        field_x     field_y    field_ra  field_dec      index_x     index_y  \
# 0   912.641541  164.096817  135.681498 -36.374811   912.557238  163.954248
# 1   634.850159  148.855301  135.658612 -36.402241   634.763981  148.596702
# 2  1125.642944  486.454865  135.736555 -36.371768  1125.530435  486.003642
# 3   919.450195  813.489502  135.760432 -36.411748   919.401163  814.011918
# 4   861.907288  684.272034  135.740422 -36.410142   861.894259  684.390086
#
#      index_ra  index_dec  index_id  field_id  match_weight         FLUX  \
# 0  135.681474 -36.374812         3         0      0.998835  4078.658203
# 1  135.658575 -36.402235        17         1      0.998791  4077.279297
# 2  135.736492 -36.371754         0         2      0.998738  4074.472412
# 3  135.760492 -36.411783        16         3      0.998609  4069.638672
# 4  135.740435 -36.410151         5         4      0.998896  3335.630615
#
#    BACKGROUND
# 0   16.341797
# 1   17.720703
# 2   20.527588
# 3   25.361328
# ...
